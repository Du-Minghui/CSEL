# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
import palettable

# %%
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Arial"
plt.rcParams['axes.unicode_minus'] = False  
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# %%
data = pd.read_csv("np_types.csv")

# %%
data
# Out:
#                                                types  num
# 0                              Class II lantipeptide  154
# 1                               Class I lantipeptide  151
# 2                                        Bacteriocin   94
# 3                                      Lasso peptide   85
# 4                    Bacterial head to tail cyclized   50
# 5                          Class III&IV lantipeptide   45
# 6                                        Thiopeptide   43
# 7   Class II lantipeptide, Class III&IV lantipeptide   33
# 8                           Thiopeptide, Bacteriocin   10
# 9                Class II lantipeptide, Prochlorosin    4
# 10                                Homoserine lactone    4
# 11   Class I lantipeptide, class III&IV lantipeptide    1
# 12                                               PLP    1

# %%
sizes = data["num"]

# %%
label = data['types']

# %%
colors=palettable.cartocolors.qualitative.Pastel_10.mpl_colors


plt.subplots(figsize=(8,8))

plt.pie(sizes,colors=colors, autopct='%.2f%%',pctdistance=1.2,radius=0.7, textprops={'fontsize': 15, 'color': 'k'},
        wedgeprops=dict(width=0.2, edgecolor='w'))

circle=plt.Circle( (0,0), 0.5, color='white')
p=plt.gcf()
p.gca().add_artist(circle)

plt.title('Types distribution(PRISM4)',fontsize=14,x=0.5,y=0.47)

plt.legend(label,bbox_to_anchor=(1.6, 0.5),loc='center right',fontsize=12,framealpha=1,fancybox=False,edgecolor='black')


#plt.tight_layout()

plt.savefig('Fig4-a.pdf', bbox_inches='tight')
plt.show()
