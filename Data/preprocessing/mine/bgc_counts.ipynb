# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("mibig_bgcs_all.csv")

# %%
df
# Out:
#          contig_id          locus_tag  protein_id  gene_start  gene_end  \
# 0       BGC0000001  unknown_locus_tag  AEK75490.1           0      1083
# 1       BGC0000001  unknown_locus_tag  AEK75490.1           0      1083
# 2       BGC0000001  unknown_locus_tag  AEK75490.1           0      1083
# 3       BGC0000001  unknown_locus_tag  AEK75490.1           0      1083
# 4       BGC0000001  unknown_locus_tag  AEK75490.1           0      1083
# ...            ...                ...         ...         ...       ...
# 126852  BGC0002749   BDW47DRAFT_71441  PLB34720.1        6609     14106
# 126853  BGC0002749   BDW47DRAFT_71441  PLB34720.1        6609     14106
# 126854  BGC0002749   BDW47DRAFT_71441  PLB34720.1        6609     14106
# 126855  BGC0002749   BDW47DRAFT_71441  PLB34720.1        6609     14106
# 126856  BGC0002749  BDW47DRAFT_134043  PLB34721.1       16129     17470
#
#         gene_strand  pfam_id  domain_start  domain_end         evalue  \
# ...

# %%
counts = df[['contig_id', 'pfam_id']].pivot_table(index='contig_id', 
                                                           columns='pfam_id',
                                                           aggfunc=np.count_nonzero).fillna(0)

# %%
counts2 = counts.astype(bool).astype(int)

# %%
counts2
# Out:
# pfam_id     PF00004  PF00005  PF00006  PF00009  PF00010  PF00011  PF00012  \
# contig_id
# BGC0000001        0        1        0        0        0        0        0
# BGC0000002        0        1        0        0        0        0        0
# BGC0000003        0        0        0        0        0        0        0
# BGC0000004        0        0        0        0        0        0        0
# BGC0000006        0        0        0        0        0        0        0
# ...             ...      ...      ...      ...      ...      ...      ...
# BGC0002736        0        0        0        0        0        0        0
# BGC0002745        0        0        0        0        0        0        0
# BGC0002746        0        0        0        0        0        0        0
# BGC0002747        0        1        0        0        0        0        0
# BGC0002749        0        0        0        0        0        0        0
#
# ...

# %%
counts2.to_csv("bgc_counts.csv")
